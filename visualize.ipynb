# %%
import pandas as pd

# %%
path ='/Users/juliushietala/Desktop/Robotics/rlkit/data/her-sac-cloth-sideways-experiment/her-sac-cloth-sideways-experiment_2020_08_05_10_01_40_0000--s-0/progress.csv'
df = pd.read_csv(path)

# %%
a = df['Epoch']
b = df['evaluation/env_infos/final/is_success Mean']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a,b)
